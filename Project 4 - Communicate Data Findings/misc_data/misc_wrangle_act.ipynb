# %% [markdown]
# ## Step 1: Importing Libraries

# %%
# Import packages
import pandas as pd

# %% [markdown]
# ## Step 2: Gathering Data

# %%
# misc_data folder
airports = pd.read_csv('misc_data/airports.csv')
carriers = pd.read_csv('misc_data/carriers.csv')
plane_data = pd.read_csv('misc_data/plane-data.csv')
var_desc = pd.read_csv('misc_data/variable-descriptions.csv')

# %% [markdown]
# ## Step 3: Assessing and Cleaning Data

# %% [markdown]
# ### Airport Data

# %%
# Looking at .info()
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 7 columns):
# iata       3376 non-null object
# airport    3376 non-null object
# city       3364 non-null object
# state      3364 non-null object
# country    3376 non-null object
# lat        3376 non-null float64
# long       3376 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 184.7+ KB

# %%
# Viewing the dataframe
airports.head()
# Out:
#   iata               airport              city state country        lat  \
# 0  00M              Thigpen        Bay Springs    MS     USA  31.953765
# 1  00R  Livingston Municipal        Livingston    TX     USA  30.685861
# 2  00V           Meadow Lake  Colorado Springs    CO     USA  38.945749
# 3  01G          Perry-Warsaw             Perry    NY     USA  42.741347
# 4  01J      Hilliard Airpark          Hilliard    FL     USA  30.688012
#
#          long
# 0  -89.234505
# 1  -95.017928
# 2 -104.569893
# 3  -78.052081
# 4  -81.905944

# %%
# Airports
airports[airports.isna().any(axis=1)]
# Out:
#      iata                       airport city state  \
# 1136  CLD    MC Clellan-Palomar Airport  NaN   NaN
# 1715  HHH                   Hilton Head  NaN   NaN
# 2251  MIB                     Minot AFB  NaN   NaN
# 2312  MQT      Marquette County Airport  NaN   NaN
# 2752  RCA                 Ellsworth AFB  NaN   NaN
# 2759  RDR               Grand Forks AFB  NaN   NaN
# 2794  ROP                   Prachinburi  NaN   NaN
# 2795  ROR              Babelthoup/Koror  NaN   NaN
# 2900  SCE               University Park  NaN   NaN
# 2964  SKA                 Fairchild AFB  NaN   NaN
# 3001  SPN  Tinian International Airport  NaN   NaN
# 3355  YAP             Yap International  NaN   NaN
#
#                              country        lat        long
# 1136                             USA  33.127231 -117.278727
# 1715                             USA  32.224384  -80.697629
# 2251                             USA  48.415769 -101.358039
# ...

# %%
airports.iloc[1136:1137]
# Out:
#      iata                     airport city state country        lat  \
# 1136  CLD  MC Clellan-Palomar Airport  NaN   NaN     USA  33.127231
#
#             long
# 1136 -117.278727

# %%
airports.loc[1136]['city']
# Out:
# nan

# %%
airports.iloc[1136:1137]
# Out:
#      iata                     airport city state country        lat  \
# 1136  CLD  MC Clellan-Palomar Airport  NaN   NaN     USA  33.127231
#
#             long
# 1136 -117.278727

# %%
airports.loc[1136, ['city']] = 'San Diego'; airports.loc[1136, ['state']] = 'CA'
airports.loc[1715, ['city']] = 'Beaufort'; airports.loc[1715, ['state']] = 'SC' 
airports.loc[2251, ['city']] = 'Minot'; airports.loc[2251, ['state']] = 'ND'
airports.loc[2312, ['city']] = 'Marquette'; airports.loc[2312, ['state']] = 'MI'
airports.loc[2752, ['city']] = 'Rapid City'; airports.loc[2752, ['state']] = 'SD'
airports.loc[2759, ['city']] = 'Grand Forks'; airports.loc[2759, ['state']] = 'ND'
airports.loc[2794, ['city']] = 'Rota Island'; airports.loc[2794, ['state']] = 'N/A'
airports.loc[2795, ['city']] = 'Babelthuap Island'; airports.loc[2795, ['state']] = 'N/A'
airports.loc[2900, ['city']] = 'State College'; airports.loc[2900, ['state']] = 'PA'
airports.loc[2964, ['city']] = 'Spokane'; airports.loc[2964, ['state']] = 'WA'
airports.loc[3001, ['city']] = 'Saipan Island'; airports.loc[3001, ['state']] = 'N/A'
airports.loc[3355, ['city']] = 'Yap Island'; airports.loc[3355, ['state']] = 'N/A'

# %% [markdown]
# Source for airport information: https://www.world-airport-codes.com/

# %%
airports.loc[[1136,1715,2251,2312,2752,2759,2794,2795,2900,2964,3001,3355]]
# Out:
#      iata                       airport               city state  \
# 1136  CLD    MC Clellan-Palomar Airport          San Diego    CA
# 1715  HHH                   Hilton Head           Beaufort    SC
# 2251  MIB                     Minot AFB              Minot    ND
# 2312  MQT      Marquette County Airport          Marquette    MI
# 2752  RCA                 Ellsworth AFB         Rapid City    SD
# 2759  RDR               Grand Forks AFB        Grand Forks    ND
# 2794  ROP                   Prachinburi        Rota Island   N/A
# 2795  ROR              Babelthoup/Koror  Babelthuap Island   N/A
# 2900  SCE               University Park      State College    PA
# 2964  SKA                 Fairchild AFB            Spokane    WA
# 3001  SPN  Tinian International Airport      Saipan Island   N/A
# 3355  YAP             Yap International         Yap Island   N/A
#
#                              country        lat        long
# 1136                             USA  33.127231 -117.278727
# ...

# %%
airports['country'].value_counts()
# Out:
# USA                               3372
# Thailand                             1
# Federated States of Micronesia       1
# N Mariana Islands                    1
# Palau                                1
# Name: country, dtype: int64

# %%
airports.loc[1136]
# Out:
# iata                              CLD
# airport    MC Clellan-Palomar Airport
# city                        San Diego
# state                              CA
# country                           USA
# lat                           33.1272
# long                         -117.279
# Name: 1136, dtype: object

# %%
airports['state'].nunique()
# Out:
# 57

# %%
airports['state'].value_counts().tail()
# Out:
# N/A    4
# CQ     4
# AS     3
# GU     1
# DC     1
# Name: state, dtype: int64

# %%
airports[airports['state'] == 'AS']
# Out:
#      iata                  airport             city state country        lat  \
# 1486  FAQ                  Fitiuta  Fitiuta Village    AS     USA  14.215776
# 2659  PPG  Pago Pago International        Pago Pago    AS     USA  14.331023
# 3361  Z08                      Ofu      Ofu Village    AS     USA  14.184351
#
#             long
# 1486 -169.423906
# 2659 -170.710526
# 3361 -169.670024

# %%
airports['city'].groupby(airports['state']).value_counts().head()
# Out:
# state  city
# AK     Anchorage    3
#        Cordova      2
#        Haines       2
#        Hoonah       2
#        Juneau       2
# Name: city, dtype: int64

# %%
airports['city'].value_counts().head(10)
# Out:
# Greenville      11
# Jackson         10
# Houston         10
# Columbus         9
# Marion           8
# Springfield      8
# Madison          8
# Lancaster        7
# Jacksonville     7
# Monticello       7
# Name: city, dtype: int64

# %%
# Checking for duplicate data
airports.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Carrier Data

# %%
carriers.head()
# Out:
#   Code                    Description
# 0  02Q                  Titan Airways
# 1  04Q             Tradewind Aviation
# 2  05Q            Comlux Aviation, AG
# 3  06Q  Master Top Linhas Aereas Ltd.
# 4  07Q            Flair Airlines Ltd.

# %%
carriers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491 entries, 0 to 1490
# Data columns (total 2 columns):
# Code           1490 non-null object
# Description    1491 non-null object
# dtypes: object(2)
# memory usage: 23.4+ KB

# %%
carriers[carriers['Code'].isna()]
# Out:
#     Code              Description
# 873  NaN  North American Airlines

# %%
# Carrier code change
carriers.loc[873, ['Code']] = 'NAA'

# %%
# Viewing our changes
carriers[carriers['Code'] == 'NAA']
# Out:
#     Code              Description
# 873  NAA  North American Airlines

# %%
# Checking for duplicate data
carriers.duplicated().sum()
# Out:
# 0

# %%
# Rename columns
carriers.rename(columns={"Code":"code", "Description":"description"}, inplace=True)

# %%
# List columns
carriers.columns
# Out:
# Index(['code', 'description'], dtype='object')

# %% [markdown]
# ### Plane Data

# %%
plane_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5029 entries, 0 to 5028
# Data columns (total 9 columns):
# tailnum          5029 non-null object
# type             4480 non-null object
# manufacturer     4480 non-null object
# issue_date       4480 non-null object
# model            4480 non-null object
# status           4480 non-null object
# aircraft_type    4480 non-null object
# engine_type      4480 non-null object
# year             4480 non-null object
# dtypes: object(9)
# memory usage: 353.7+ KB

# %%
plane_data = plane_data.dropna()

# %%
plane_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4480 entries, 34 to 5028
# Data columns (total 9 columns):
# tailnum          4480 non-null object
# type             4480 non-null object
# manufacturer     4480 non-null object
# issue_date       4480 non-null object
# model            4480 non-null object
# status           4480 non-null object
# aircraft_type    4480 non-null object
# engine_type      4480 non-null object
# year             4480 non-null object
# dtypes: object(9)
# memory usage: 350.0+ KB

# %%
plane_data.head()
# Out:
#    tailnum         type      manufacturer  issue_date      model status  \
# 34  N10156  Corporation           EMBRAER  02/13/2004  EMB-145XR  Valid
# 35  N102UW  Corporation  AIRBUS INDUSTRIE  05/26/1999   A320-214  Valid
# 36  N10323  Corporation            BOEING  07/01/1997    737-3TO  Valid
# 37  N103US  Corporation  AIRBUS INDUSTRIE  06/18/1999   A320-214  Valid
# 38  N104UA  Corporation            BOEING  01/26/1998    747-422  Valid
#
#               aircraft_type engine_type  year
# 34  Fixed Wing Multi-Engine   Turbo-Fan  2004
# 35  Fixed Wing Multi-Engine   Turbo-Fan  1998
# 36  Fixed Wing Multi-Engine   Turbo-Jet  1986
# 37  Fixed Wing Multi-Engine   Turbo-Fan  1999
# 38  Fixed Wing Multi-Engine   Turbo-Fan  1998

# %%
plane_data['manufacturer'].value_counts()
# Out:
# BOEING                            2061
# EMBRAER                            588
# BOMBARDIER INC                     547
# AIRBUS INDUSTRIE                   434
# MCDONNELL DOUGLAS                  253
# AIRBUS                             244
# MCDONNELL DOUGLAS AIRCRAFT CO      105
# CANADAIR                            86
# DOUGLAS                             36
# SAAB-SCANIA                         28
# DEHAVILLAND                         17
# MCDONNELL DOUGLAS CORPORATION       14
# CESSNA                              12
# AEROSPATIALE                         8
# AEROSPATIALE/ALENIA                  6
# PIPER                                6
# BEECH                                5
# RAVEN                                3
# SIKORSKY                             3
# GULFSTREAM AEROSPACE                 2
# AERO COMMANDER                       2
# MAULE                                2
# AVIAT AIRCRAFT INC                   2
# BAUMAN RANDY                         1
# ...

# %%
plane_data[plane_data['manufacturer'] == 'MCDONNELL DOUGLAS CORPORATION']
# Out:
#      tailnum         type                   manufacturer  issue_date  model  \
# 4403  N900DE  Corporation  MCDONNELL DOUGLAS CORPORATION  03/30/1992  MD-88
# 4409  N901DE  Corporation  MCDONNELL DOUGLAS CORPORATION  04/29/1992  MD-88
# 4417  N902DE  Corporation  MCDONNELL DOUGLAS CORPORATION  05/01/1992  MD-88
# 4425  N903DE  Corporation  MCDONNELL DOUGLAS CORPORATION  05/08/1992  MD-88
# 4435  N904DE  Corporation  MCDONNELL DOUGLAS CORPORATION  06/03/1992  MD-88
# 4444  N905DE  Corporation  MCDONNELL DOUGLAS CORPORATION  06/03/1992  MD-88
# 4458  N906DE  Corporation  MCDONNELL DOUGLAS CORPORATION  11/03/1992  MD-88
# 4468  N907DE  Corporation  MCDONNELL DOUGLAS CORPORATION  11/10/1992  MD-88
# 4479  N908DE  Corporation  MCDONNELL DOUGLAS CORPORATION  12/04/1992  MD-88
# 4489  N909DE  Corporation  MCDONNELL DOUGLAS CORPORATION  12/10/1992  MD-88
# 4498  N910DE  Corporation  MCDONNELL DOUGLAS CORPORATION  12/28/1992  MD-88
# ...

# %%
plane_data[plane_data['manufacturer'] == 'DOUGLAS']
# Out:
#      tailnum         type manufacturer  issue_date    model status  \
# 162   N1309T  Corporation      DOUGLAS  06/17/2004  DC-9-31  Valid
# 178   N1334U  Corporation      DOUGLAS  12/22/1986  DC-9-31  Valid
# 526   N1799U  Corporation      DOUGLAS  12/22/1986  DC-9-31  Valid
# 1145  N3324L  Corporation      DOUGLAS  12/02/1994  DC-9-32  Valid
# 1473  N381AA  Corporation      DOUGLAS  12/21/1998   DC-7BF  Valid
# 3582  N750NW  Corporation      DOUGLAS  05/03/1996  DC-9-41  Valid
# 3595  N752NW  Corporation      DOUGLAS  07/01/1996  DC-9-41  Valid
# 3600  N753NW  Corporation      DOUGLAS  05/03/1996  DC-9-41  Valid
# 3618  N756NW  Corporation      DOUGLAS  06/28/1996  DC-9-41  Valid
# 4354  N8920E  Corporation      DOUGLAS  08/02/1994  DC-9-31  Valid
# 4356  N8921E  Corporation      DOUGLAS  08/02/1994  DC-9-31  Valid
# 4358  N8923E  Corporation      DOUGLAS  08/02/1994  DC-9-31  Valid
# 4360  N8925E  Corporation      DOUGLAS  08/02/1994  DC-9-31  Valid
# ...

# %%
# Checking for duplicate data
plane_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Variable Descriptions

# %%
var_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 3 columns):
# Variable descriptions    29 non-null float64
# Unnamed: 1               30 non-null object
# Unnamed: 2               30 non-null object
# dtypes: float64(1), object(2)
# memory usage: 824.0+ bytes

# %%
var_desc.head(30)
# Out:
#     Variable descriptions         Unnamed: 1  \
# 0                     NaN                NaN
# 1                     NaN               Name
# 2                     1.0               Year
# 3                     2.0              Month
# 4                     3.0         DayofMonth
# 5                     4.0          DayOfWeek
# 6                     5.0            DepTime
# 7                     6.0         CRSDepTime
# 8                     7.0            ArrTime
# 9                     8.0         CRSArrTime
# 10                    9.0      UniqueCarrier
# 11                   10.0          FlightNum
# 12                   11.0            TailNum
# 13                   12.0  ActualElapsedTime
# 14                   13.0     CRSElapsedTime
# 15                   14.0            AirTime
# 16                   15.0           ArrDelay
# 17                   16.0           DepDelay
# 18                   17.0             Origin
# 19                   18.0               Dest
# ...

# %%
# Rename columns
var_desc.rename(columns={"Unnamed: 1":"name", "Unnamed: 2":"description"}, inplace=True)

# %%
var_desc = var_desc.dropna()

# %%
var_desc.head()
# Out:
#    Variable descriptions        name                          description
# 2                    1.0        Year                            1987-2008
# 3                    2.0       Month                               12-Jan
# 4                    3.0  DayofMonth                               31-Jan
# 5                    4.0   DayOfWeek              1 (Monday) - 7 (Sunday)
# 6                    5.0     DepTime  actual departure time (local, hhmm)

# %%
var_desc.drop(['Variable descriptions'], axis=1, inplace=True)
var_desc = var_desc.reset_index(drop=True)

# %%
var_desc
# Out:
#                  name                                        description
# 0                Year                                          1987-2008
# 1               Month                                             12-Jan
# 2          DayofMonth                                             31-Jan
# 3           DayOfWeek                            1 (Monday) - 7 (Sunday)
# 4             DepTime                actual departure time (local, hhmm)
# 5          CRSDepTime             scheduled departure time (local, hhmm)
# 6             ArrTime                  actual arrival time (local, hhmm)
# 7          CRSArrTime               scheduled arrival time (local, hhmm)
# 8       UniqueCarrier                                unique carrier code
# 9           FlightNum                                      flight number
# 10            TailNum                                  plane tail number
# 11  ActualElapsedTime                                         in minutes
# ...

# %% [markdown]
# ## Step 4: Saving Data

# %% [raw]
# # To prevent the index data being stored twice we can add: index=False
# airports.to_csv('misc_data/master/airports_master.csv', index=False)
# carriers.to_csv('misc_data/master/carriers_master.csv', index=False)
# plane_data.to_csv('misc_data/master/plane-data_master.csv', index=False)
# var_desc.to_csv('misc_data/master/variable-descriptions_master.csv', index=False)

# %%
import timeit
import numpy

# %%
# %%timeit
airports.groupby('city').mean()
# Out:
# 2.16 ms ± 6.81 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
